# %% [markdown]
# # Image load test
# May 30, 2021 Sunday, Jennifer E Yoon
# Repo:  geo-ml/tests/

# %%
from PIL import Image
from pathlib import Path

import numpy as np 
import matplotlib.pyplot as plt 
# %matplotlib notebook

# %%
Path?

# %%
np
# Out:
# <module 'numpy' from 'c:\\python\\python\\lib\\site-packages\\numpy\\__init__.py'>

# %%
folder = Path('../cats/')
folder
# Out:
# WindowsPath('../cats')

# %%
fn = 'cat_01.jpg'
obj = folder / fn
#with open(obj) as file:  
#    print(file)
    
img = Image.open(obj)
print(img.mode)
print(type(img))
img
# Out:
# RGB
# <class 'PIL.JpegImagePlugin.JpegImageFile'>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=300x168 at 0x258C47262B0>

# %%
lst = ['cat_00.jpg', 'cat_01.jpg', 'cat_02.jpg', 'cat_03.jpg']
type(lst)
# Out:
# list

# %%
np.size(img)
# Out:
# (300, 168)

# %%
batch = []
for i in range(4):  
    fi = folder / lst[i]
    print(fi)
    batch.append(fi)
    
print(batch)
# Out:
# ..\cats\cat_00.jpg
# ..\cats\cat_01.jpg
# ..\cats\cat_02.jpg
# ..\cats\cat_03.jpg
# [WindowsPath('../cats/cat_00.jpg'), WindowsPath('../cats/cat_01.jpg'), WindowsPath('../cats/cat_02.jpg'), WindowsPath('../cats/cat_03.jpg')]

# %%
type(batch[0])
# Out:
# pathlib.WindowsPath

# %%
obj2 = folder / 'cat_00.jpg'
img2 = Image.open(obj2)
import matplotlib.pyplot as plt
f,ax = plt.subplots(1,4)
for i in range(4):
    ax[i].imshow(img2)
plt.show()

# %%
obj2 = folder / 'cat_00.jpg'
img2 = Image.open(obj2)

f,ax = plt.subplots(1,4)
for i in range(4):
    ax[i].imshow(img2)
plt.show()
